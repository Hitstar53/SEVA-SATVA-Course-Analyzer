# %% [markdown]
# ### Preprocessing ODD Sem 22-23

# %%
import pandas as pd
import os
data_dir = '../data'

# %% [markdown]
# Courses:

# %%
courses = pd.read_csv(os.path.join(data_dir, 'courses.csv'))
courses.head()
# Out:
#    course_id                            course_name   category
# 0          1                          Art of living  Spiritual
# 1          2            Introduction to Bhagvadgita  Spiritual
# 2          3                              Pranvidya  Spiritual
# 3          4                              Yog Vidya  Spiritual
# 4          5  Mentoring School Children (Abhyudaya)     Social

# %%
df = pd.read_excel(os.path.join(data_dir, 'original/odd sem 2022-23.xlsx'), sheet_name=1)
df.head(10)
# Out:
#                    Email Address Name (as in the college records)     UID No.  \
# 0      adeika.dikshit@spit.ac.in                   Adrika Dikshit  2020100012
# 1       vaibhav.raina@spit.ac.in              Vaibhav Vinod Raina  2018110040
# 2         niraj.dhodi@spit.ac.in                      Niraj Dhodi  2018120018
# 3         rohit.gupta@spit.ac.in                      Rohit Gupta  2021200035
# 4        shivam.patel@spit.ac.in            Shivam Dhansukh Patel  2018120047
# 5       shubham.surve@spit.ac.in                    Shubham Surve  2021200113
# 6  ajeyaraj.upadhyaya@spit.ac.in      Ajeyaraj Ramadasa Upadhyaya  2021600070
# 7       sanchit.patil@spit.ac.in             Sanchit Tanaji Patil  2021200089
# 8           sridhar.a@spit.ac.in                          SRIDHAR  2021200115
# 9        ankit.prasad@spit.ac.in                     Ankit Prasad  2021200097
#
#   Class (to be entered in next Semester)    Branch  \
# 0                                     TY      ETRX
# 1                                B. Tech      ETRX
# 2                                B. Tech      EXTC
# 3                                     SY      EXTC
# 4                                B. Tech      EXTC
# 5                                     SY      EXTC
# 6                                     SY  CSE-AIML
# 7                                     SY      EXTC
# 8                                     SY      EXTC
# 9                                     SY      EXTC
#
#                      Course Allocated  Sem
# 0  Integrated Personality Development    5
# 1  Integrated Personality Development    7
# 2  Integrated Personality Development    7
# 3  Integrated Personality Development    3
# 4  Integrated Personality Development    7
# 5  Integrated Personality Development    3
# 6  Integrated Personality Development    3
# 7  Integrated Personality Development    3
# 8  Integrated Personality Development    3
# 9  Integrated Personality Development    3

# %%
courses = pd.read_csv(os.path.join(data_dir, 'courses.csv'))
course_names = courses['course_name'].tolist()
course_names
# Out:
# ['Art of living',
#  'Introduction to Bhagvadgita',
#  'Pranvidya',
#  'Yog Vidya',
#  'Mentoring School Children (Abhyudaya)',
#  'Mentorship to Juniors',
#  'NSS',
#  'Principle Centered Leadership',
#  'Teaching Assistantship',
#  'Terrace Gardening',
#  "Volunteering at Dr. Amte's Anandvan",
#  'Wall Painting',
#  'Working with NGO',
#  'Astitva',
#  'Kathak',
#  'Physical Fitness',
#  'Running',
#  'Self Defense for Women',
#  'Skipping',
#  'Sports',
#  'Staircase Climbing',
#  'Swimming',
#  'Taekwondo',
#  'Trekking',
#  'Basic Cooking',
#  'Basics of Fire Safety',
#  'Basics of Keyboard playing',
#  'Basics of Music Composition',
#  'Design Thinking',
#  'Film Appreciation',
#  'Fundamentals of Photography',
#  'Idea Lab',
#  'Indian Knowledge System',
#  'Innovation and Creativity',
#  'Read a book',
#  'Cinematography',
#  'Social Psychology',
#  'Study of Life',
#  'Technology Entrepreneurship',
#  'Integrated Personality Development',
#  'Jeevan Vidya (Work Life Balance)',
#  'Universal Human Value']

# %% [markdown]
# After cleaning some data in excel, normalizing rest of the courses:

# %%
sheet1 = pd.read_csv(os.path.join(data_dir, 'sheet-1.csv'))
sheet1['course'].unique()
# Out:
# array(['Social Psychology', 'Integrated Personality Development',
#        'Physical Fitness', 'Self Defense for Women', 'Pranvidya',
#        'Kathak', 'Basics of Music Composition', 'Film Appreciation',
#        'Fundamentals of Photography', 'Basics of Keyboard playing',
#        'Cinematography', 'Principle Centered Leadership', 'Read a book',
#        'Course Allocated', 'Basics of Fire Safety',
#        'Mentoring School Children (Abhyudaya)', 'Teaching Assistantship',
#        'Jeevan Vidya (Work Life Balance)', 'Mentorship to Juniors',
#        'Indian Knowledge System', 'Design Thinking',
#        'Innovation and Creativity'], dtype=object)

# %%
not_matching = [i for i in sheet1['course'].unique() if i not in course_names]
not_matching
# Out:
# ['Course Allocated']

# %% [markdown]
# Deleting the rows with 'Course Allocated' in course column:

# %%
sheet1.drop(sheet1[sheet1['course'] == 'Course Allocated'].index, inplace=True)
not_matching = [i for i in sheet1['course'].unique() if i not in course_names]
not_matching
# Out:
# []

# %% [markdown]
# Converting all names to title case:

# %%
sheet1['name'] = sheet1['name'].map(lambda x: x.strip().title())

# %%
sheet1.head(20)
# Out:
#                               email                        name         uid  \
# 0         navinder.singh@spit.ac.in              Navinder Singh  2020200058
# 1         nathan.cardoso@spit.ac.in         Nathan Jude Cardoso  2021600009
# 2           akim.chowhan@spit.ac.in           Akim Akil Chowhan  2020400005
# 3      rashmi.rajeshirke@spit.ac.in  Rashmi Samarjit Rajeshirke  2021700051
# 4         mohit.narwaiye@spit.ac.in              Mohit Narwaiye  2021300085
# 5           pratham.jain@spit.ac.in                Pratham Jain  2021300051
# 6           nikita.pawar@spit.ac.in          Nikita Sunil Pawar  2021300098
# 7         sakshi.phapale@spit.ac.in      Sakshi Malhari Phapale  2021700049
# 8   krishnan.subramanian@spit.ac.in        Krishnan Subramanian  2021300130
# 9        malavika.kanady@spit.ac.in      Malavika Vishnu Kanady  2021200051
# 10          ronak.thakar@spit.ac.in         Ronak Satish Thakar  2021700066
# 11      janhavi.deshmukh@spit.ac.in        Janhavi Ram Deshmukh  2021700017
# 12         aniket.sawant@spit.ac.in               Aniket Sawant  2021401077
# 13     adwait.nyayadhish@spit.ac.in      Adwait Atul Nyayadhish  2021401076
# 14     prathamesh.renghe@spit.ac.in     Prathamesh Sunil Renghe  2021401073
# 15       arbaaz.ghameria@spit.ac.in      Arbaaz Haroon Ghameria  2021401075
# 16        adeika.dikshit@spit.ac.in              Adrika Dikshit  2020100012
# 17         vaibhav.raina@spit.ac.in         Vaibhav Vinod Raina  2018110040
# 18           niraj.dhodi@spit.ac.in                 Niraj Dhodi  2018120018
# 19           rohit.gupta@spit.ac.in                 Rohit Gupta  2021200035
#
#       branch sem                              course
# 0       EXTC   5                   Social Psychology
# 1   CSE-AIML   3                   Social Psychology
# 2         IT   5                   Social Psychology
# 3     CSE-DS   3                   Social Psychology
# 4       COMP   3                   Social Psychology
# 5       COMP   3                   Social Psychology
# 6       COMP   3                   Social Psychology
# 7     CSE-DS   3                   Social Psychology
# 8       COMP   3                   Social Psychology
# 9       EXTC   3                   Social Psychology
# 10    CSE-DS   3                   Social Psychology
# 11    CSE-DS   3                   Social Psychology
# 12        IT   5                   Social Psychology
# 13        IT   5                   Social Psychology
# 14        IT   5                   Social Psychology
# 15        IT   5                   Social Psychology
# 16      ETRX   5  Integrated Personality Development
# 17      ETRX   7  Integrated Personality Development
# 18      EXTC   7  Integrated Personality Development
# 19      EXTC   3  Integrated Personality Development

# %%
sheet1.sort_values(by=['course', 'sem', 'branch', 'uid'], ascending=True, inplace=True)
sheet1.head(20)
# Out:
#                             email                        name         uid  \
# 802       shaun.dsouza@spit.ac.in               Shaun D'Souza  2021300031
# 766   ganesh.chaudhari@spit.ac.in            Ganesh Chaudhari  2021510007
# 771     chetan.dhandge@spit.ac.in              Chetan Dhandge  2021510010
# 752      sudhir.gomase@spit.ac.in       Sudhir Narayan Gomase  2021510018
# 738       vishal.padme@spit.ac.in        Vishal Devidas Padme  2021510041
# 794      pratik.parale@spit.ac.in               Pratik Parale  2021510045
# 795        amit.rathod@spit.ac.in         Amit Manohar Rathod  2021510053
# 749    sandesh.shivane@spit.ac.in             Sandesh Shivane  2021510063
# 805    prashant.singh2@spit.ac.in              Prashant Singh  2021510064
# 810       rahul.shinde@spit.ac.in   Rahul Pandharinath Shinde  2021600061
# 764  bhavesh.chaudhari@spit.ac.in  Bhavesh Prashant Chaudhari  2021300018
# 801      parth.gandhi2@spit.ac.in                Parth Gandhi  2021300033
# 800     deepak.ganwani@spit.ac.in              Deepak Ganwani  2021300035
# 799        hardik.garg@spit.ac.in                 Hardik Garg  2021300036
# 741       palaash.jain@spit.ac.in          Palaash Lalit Jain  2021300050
# 792    akshaya.karande@spit.ac.in             Akshaya Karande  2021300056
# 791    harshey.kaursoi@spit.ac.in            Harshey Kaur Soi  2021300057
# 765     vaibhav.mahale@spit.ac.in              Vaibhav Mahale  2021300071
# 778     reshma.dhadwad@spit.ac.in              Reshma Dhadwad  2021700019
# 750    tanmay.kulkarni@spit.ac.in             Tanmay Kulkarni  2021700033
#
#      branch sem                 course
# 802    COMP   1  Basics of Fire Safety
# 766     MCA   1  Basics of Fire Safety
# 771     MCA   1  Basics of Fire Safety
# 752     MCA   1  Basics of Fire Safety
# 738     MCA   1  Basics of Fire Safety
# 794     MCA   1  Basics of Fire Safety
# 795     MCA   1  Basics of Fire Safety
# 749     MCA   1  Basics of Fire Safety
# 805     MCA   1  Basics of Fire Safety
# 810   AI-ML   3  Basics of Fire Safety
# 764    COMP   3  Basics of Fire Safety
# 801    COMP   3  Basics of Fire Safety
# 800    COMP   3  Basics of Fire Safety
# 799    COMP   3  Basics of Fire Safety
# 741    COMP   3  Basics of Fire Safety
# 792    COMP   3  Basics of Fire Safety
# 791    COMP   3  Basics of Fire Safety
# 765    COMP   3  Basics of Fire Safety
# 778  CSE-DS   3  Basics of Fire Safety
# 750  CSE-DS   3  Basics of Fire Safety

# %%
sheet1.to_csv(os.path.join(data_dir, 'sheet-1.csv'), index=False)

# %% [markdown]
# Deleting duplicate rows:

# %%
print(f'Number of duplicate rows: {sheet1.duplicated().sum()} / {sheet1.shape[0]}')
# Out:
# Number of duplicate rows: 1 / 1196

# %%
sheet1.loc[sheet1.duplicated(), :]
# Out:
#                         email                   name         uid branch sem  \
# 712  gaurang.gawas@spit.ac.in  Gaurang Shankar Gawas  2021201071   EXTC   5
#
#           course
# 712  Read a book

# %%
sheet1.drop_duplicates(inplace=True, keep='first', ignore_index=True)

# %%
sheet1.shape[0]
# Out:
# 1195

# %%
sheet1.to_csv(os.path.join(data_dir, 'sheet-1.csv'), index=False)

# %% [markdown]
# Checking for duplicates based on email:

# %%
sheet1.duplicated(subset=['email']).sum()
# Out:
# 40

# %%
duplicate_emails = set(sheet1['email'][sheet1.duplicated(subset=['email'])].values)
duplicated_rows = sheet1[sheet1['email'].map(lambda x: x in duplicate_emails)].sort_values(by='email')
duplicated_rows
# Out:
#                              email                    name         uid branch  \
# 280      abhinav.hadole@spit.ac.in          Abhinav Hadole  2021101070   ETRX
# 221      abhinav.hadole@spit.ac.in          Abhinav Hadole  2021101070   ETRX
# 1139  adwait.nyayadhish@spit.ac.in  Adwait Atul Nyayadhish  2021401076     IT
# 474   adwait.nyayadhish@spit.ac.in  Adwait Atul Nyayadhish  2021401076     IT
# 437    amaresh.baranwal@spit.ac.in        Amaresh Baranwal  2021301073   COMP
# ...                            ...                     ...         ...    ...
# 186          utsav.kaim@spit.ac.in              Utsav Kaim  2020200030   EXTC
# 902     vaibhav.udamale@spit.ac.in         Vaibhav Udamale  2021401078     IT
# 475     vaibhav.udamale@spit.ac.in         Vaibhav Udamale  2021401078     IT
# 287    virendra.mahajan@spit.ac.in        Virendra Mahajan  2021201079   EXTC
# 466    virendra.mahajan@spit.ac.in        Virendra Mahajan  2021201079   EXTC
#
#      sem                       course
# 280    5              Design Thinking
# 221    5               Cinematography
# 1139   5            Social Psychology
# 474    5  Fundamentals of Photography
# 437    5  Fundamentals of Photography
# ...   ..                          ...
# 186    5  Basics of Music Composition
# 902    5                    Pranvidya
# 475    5  Fundamentals of Photography
# 287    5              Design Thinking
# 466    5  Fundamentals of Photography
#
# [80 rows x 6 columns]

# %%
duplicated_rows.to_csv(os.path.join(data_dir, 'sheet-1-duplicated-rows.csv'), index=False)

# %% [markdown]
# Joiining with the courses df:

# %%
cols_to_keep = list(sheet1.columns) + ['category']
sheet1 = pd.merge(sheet1, courses, left_on='course', right_on='course_name')[cols_to_keep]
sheet1
# Out:
#                             email                   name         uid branch  \
# 0         shaun.dsouza@spit.ac.in          Shaun D'Souza  2021300031   COMP
# 1     ganesh.chaudhari@spit.ac.in       Ganesh Chaudhari  2021510007    MCA
# 2       chetan.dhandge@spit.ac.in         Chetan Dhandge  2021510010    MCA
# 3        sudhir.gomase@spit.ac.in  Sudhir Narayan Gomase  2021510018    MCA
# 4         vishal.padme@spit.ac.in   Vishal Devidas Padme  2021510041    MCA
# ...                           ...                    ...         ...    ...
# 1190      jeenal.mehta@spit.ac.in           Jeenal Mehta  2019140039     IT
# 1191       mihir.nikam@spit.ac.in            Mihir Nikam  2019140042     IT
# 1192      rushil.patel@spit.ac.in           Rushil Patel  2019140047     IT
# 1193      ameya.ranade@spit.ac.in           Ameya Ranade  2019140053     IT
# 1194       manan.savla@spit.ac.in            Manan Savla  2019140055     IT
#
#      sem                  course      category
# 0      1   Basics of Fire Safety  Intellectual
# 1      1   Basics of Fire Safety  Intellectual
# 2      1   Basics of Fire Safety  Intellectual
# 3      1   Basics of Fire Safety  Intellectual
# 4      1   Basics of Fire Safety  Intellectual
# ...   ..                     ...           ...
# 1190   7  Teaching Assistantship        Social
# 1191   7  Teaching Assistantship        Social
# 1192   7  Teaching Assistantship        Social
# 1193   7  Teaching Assistantship        Social
# 1194   7  Teaching Assistantship        Social
#
# [1195 rows x 7 columns]

# %%
sheet1.to_csv(os.path.join(data_dir, 'sheet-1.csv'), index=False)
